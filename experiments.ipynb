# %% [markdown]
# # Experiments

# %%
# import subprocess, tempfile, pathlib

# def midi_to_wav(midi_path, sf_path, wav_path):
#     subprocess.run(
#         ["fluidsynth", "-ni", sf_path, midi_path, "-F", wav_path, "-r", "44100"],
#         check=True,
#         stdout=subprocess.DEVNULL,
#         stderr=subprocess.DEVNULL,
#     )

# from IPython.display import Audio
# Audio("output.wav")

# import pretty_midi, pandas as pd

# pm = pretty_midi.PrettyMIDI("song.mid")
# rows = []
# for inst_idx, inst in enumerate(pm.instruments):
#     for note in inst.notes:
#         rows.append({
#             "instrument": inst_idx,
#             "start": note.start,
#             "end": note.end,
#             "pitch": note.pitch,
#             "velocity": note.velocity,
#         })
# note_df = pd.DataFrame(rows)
